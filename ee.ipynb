# %%
import numpy as np
import matplotlib.pyplot as plt

import modules_py.functions as f
import modules_py.functions_vec as fv

plt.style.use('publication23.mplstyle')

# %%
# pf = 1.28 # pf 0.89, 1.12, 1.28 | n 0.1, 0.2, 0.3

f.M = 6.67

plt.plot(fv.k, -fv.eq_pnn(fv.k, 0, 0.89).real, label=r'$n = %.1f n_0$' % f.n(0.89), ls='-', color='red')
plt.plot(fv.k, -fv.eq_pnn(fv.k, 0, 1.12).real, label=r'$n = %.1f n_0$' % f.n(1.12), ls='--', color='green')
plt.plot(fv.k, -fv.eq_pnn(fv.k, 0, 1.28).real, label=r'$n = %.1f n_0$' % f.n(1.28), ls=':', color='blue')

plt.axhline(y=0, ls=':', lw=1, color='black')

plt.xlim(0, 5)
plt.ylim(-1, 5)

plt.xlabel(r'$k$')
plt.title(r'eq$(\omega = 0, k)$')
plt.legend(frameon=False)

# plt.savefig('/Users/vladlen/Desktop/sci_temp/ee_eq_pnn_w0.jpg', dpi=300, format='JPG', bbox_inches='tight')
plt.show()

# %%
f.M = 6.67 * 0.9
f.G_MINUS = 1.6

# pf = 1.28 # pf 0.89, 1.12, 1.28 | n 0.1, 0.2, 0.3

plt.plot(fv.k, -fv.eq_pnn_corr(fv.k, 0, 1.91).real, label=r'$n = %.1f n_0$' % f.n(1.91), ls='-', color='red')
plt.plot(fv.k, -fv.eq_pnn_corr(fv.k, 0, 3.47).real, label=r'$n = %.1f n_0$' % f.n(3.47), ls='--', color='green')
plt.plot(fv.k, -fv.eq_pnn_corr(fv.k, 0, 3.65).real, label=r'$n = %.1f n_0$' % f.n(3.65), ls=':', color='blue')

plt.axhline(y=0, ls=':', lw=1, color='black')

plt.xlim(0, 5)
plt.ylim(-1, 5)

plt.xlabel(r'$k$')
plt.title(r'eq$(\omega = 0, k)$')
plt.legend(frameon=False)

plt.savefig('/Users/vladlen/Desktop/sci_temp/ee_eq_pnn_corr_g1.6_w0.jpg', dpi=300, format='JPG', bbox_inches='tight')
plt.show()
